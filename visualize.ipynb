# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
general_path = 'fmnist-exp/Baseline_exps/'
experiment_paths = ['Base1/', 'Base2/', 'Base3/', 'Base4/', 'Base5/']

# %%
base1_c0_df = pd.read_csv(general_path + 'Base1/client0.csv')
base1_c1_df = pd.read_csv(general_path + 'Base1/client1.csv')

base2_c0_df = pd.read_csv(general_path + 'Base2/client0.csv')
base2_c1_df = pd.read_csv(general_path + 'Base2/client1.csv')

base3_c0_df = pd.read_csv(general_path + 'Base3/client0.csv')
base3_c1_df = pd.read_csv(general_path + 'Base3/client1.csv')

base4_c0_df = pd.read_csv(general_path + 'Base4/client0.csv')
base4_c1_df = pd.read_csv(general_path + 'Base4/client1.csv')

base5_c0_df = pd.read_csv(general_path + 'Base5/client0.csv')
base5_c1_df = pd.read_csv(general_path + 'Base5/client1.csv')

# %%
sns.set_style('whitegrid', {'grid.color': '0.7'})

# %% [markdown]
# ### Learning Curves

# %%
plt.figure(figsize=(5, 3))

sns.lineplot(data=base1_c0_df, x='epoch', y='training_loss', linestyle='dotted', color='purple') 
sns.lineplot(data=base2_c0_df, x='epoch', y='training_loss', linestyle='dotted', color='red')
sns.lineplot(data=base3_c0_df, x='epoch', y='training_loss', linestyle='dotted', color='blue')
sns.lineplot(data=base4_c0_df, x='epoch', y='training_loss', linestyle='dotted', color='green')
sns.lineplot(data=base5_c0_df, x='epoch', y='training_loss', linestyle='dotted', color='#EDB120')

sns.lineplot(data=base1_c1_df, x='epoch', y='training_loss', linestyle='dashed', color='purple')
sns.lineplot(data=base2_c1_df, x='epoch', y='training_loss', linestyle='dashed', color='red')
sns.lineplot(data=base3_c1_df, x='epoch', y='training_loss', linestyle='dotted', color='blue')
sns.lineplot(data=base4_c1_df, x='epoch', y='training_loss', linestyle='dashed', color='green')
sns.lineplot(data=base5_c1_df, x='epoch', y='training_loss', linestyle='dashed', color='#EDB120')

plt.xlabel('Epochs')
plt.ylabel('Training Loss')
plt.xlim(left=0, right=70)

line1, = plt.plot([], linestyle='dotted', color='black')
line2, = plt.plot([], linestyle='dashed', color='black')
line3, = plt.plot([], linestyle='solid', color='blue')
line4, = plt.plot([], linestyle='solid', color='red')
line5, = plt.plot([], linestyle='solid', color='#EDB120')
line6, = plt.plot([], linestyle='solid', color='purple')
line7, = plt.plot([], linestyle='solid', color='green')

plt.legend([line1, line2, line3, line4, line5, line6, line7], ['Client 1', 'Client 2', 'λ = 0', 'λ = 0.2', 'λ = 0.3', 'λ = 0.5', 'λ = 0.9'], title='', loc='upper right', fontsize='large')
#plt.savefig("fmnist-exp/Figures/Learning Curves/clients.pdf", dpi=100000)
_ = plt.show()

# %%
plt.figure(figsize=(12, 9))

sns.lineplot(data=base1_c0_df, x='epoch', y='training_loss', linestyle='dotted', color='purple')
sns.lineplot(data=base2_c0_df, x='epoch', y='training_loss', linestyle='dotted', color='red')
sns.lineplot(data=base3_c0_df, x='epoch', y='training_loss', linestyle='dotted', color='blue')
sns.lineplot(data=base4_c0_df, x='epoch', y='training_loss', linestyle='dotted', color='green')
sns.lineplot(data=base5_c0_df, x='epoch', y='training_loss', linestyle='dotted', color='#EDB120')

sns.lineplot(data=base1_c0_df, x='epoch', y='server_training_loss', linestyle='dashed', color='purple')
sns.lineplot(data=base2_c0_df, x='epoch', y='server_training_loss', linestyle='dashed', color='red')
sns.lineplot(data=base3_c0_df, x='epoch', y='server_training_loss', linestyle='dashed', color='blue')
sns.lineplot(data=base4_c0_df, x='epoch', y='server_training_loss', linestyle='dashed', color='green')
sns.lineplot(data=base5_c0_df, x='epoch', y='server_training_loss', linestyle='dashed', color='#EDB120')

plt.xlabel('Epochs')
plt.ylabel('Training Loss')
plt.xlim(left=0, right=70)

line1, = plt.plot([], linestyle='dotted', color='black')
line2, = plt.plot([], linestyle='dashed', color='black')
line3, = plt.plot([], linestyle='solid', color='blue')
line4, = plt.plot([], linestyle='solid', color='red')
line5, = plt.plot([], linestyle='solid', color='#EDB120')
line6, = plt.plot([], linestyle='solid', color='purple')
line7, = plt.plot([], linestyle='solid', color='green')

plt.legend([line1, line2, line3, line4, line5, line6, line7], ['Client 1', 'Server', 'λ = 0', 'λ = 0.2', 'λ = 0.3', 'λ = 0.5', 'λ = 0.9'], title='', loc='upper right', fontsize='large')
plt.savefig("fmnist-exp/Figures/Learning Curves/client1_server.pdf", dpi=100000)

_ = plt.show()

# %%
plt.figure(figsize=(12, 9))

sns.lineplot(data=base1_c1_df, x='epoch', y='training_loss', linestyle='dotted', color='purple')
sns.lineplot(data=base2_c1_df, x='epoch', y='training_loss', linestyle='dotted', color='red')
sns.lineplot(data=base3_c1_df, x='epoch', y='training_loss', linestyle='dotted', color='blue')
sns.lineplot(data=base4_c1_df, x='epoch', y='training_loss', linestyle='dotted', color='green')
sns.lineplot(data=base5_c1_df, x='epoch', y='training_loss', linestyle='dotted', color='#EDB120')

sns.lineplot(data=base1_c1_df, x='epoch', y='server_training_loss', linestyle='dashed', color='purple')
sns.lineplot(data=base2_c1_df, x='epoch', y='server_training_loss', linestyle='dashed', color='red')
sns.lineplot(data=base3_c1_df, x='epoch', y='server_training_loss', linestyle='dashed', color='blue')
sns.lineplot(data=base4_c1_df, x='epoch', y='server_training_loss', linestyle='dashed', color='green')
sns.lineplot(data=base5_c1_df, x='epoch', y='server_training_loss', linestyle='dashed', color='#EDB120')

plt.xlabel('Epochs')
plt.ylabel('Training Loss')
plt.xlim(left=0, right=70)

line1, = plt.plot([], linestyle='dotted', color='black')
line2, = plt.plot([], linestyle='dashed', color='black')
line3, = plt.plot([], linestyle='solid', color='blue')
line4, = plt.plot([], linestyle='solid', color='red')
line5, = plt.plot([], linestyle='solid', color='#EDB120')
line6, = plt.plot([], linestyle='solid', color='purple')
line7, = plt.plot([], linestyle='solid', color='green')

plt.legend([line1, line2, line3, line4, line5, line6, line7], ['Client 2', 'Server', 'λ = 0', 'λ = 0.2', 'λ = 0.3', 'λ = 0.5', 'λ = 0.9'], title='', loc='upper right', fontsize='large')
plt.savefig("fmnist-exp/Figures/Learning Curves/client2_server.pdf", dpi=100000)

_ = plt.show()

# %%
plt.figure(figsize=(12, 9))

sns.lineplot(data=base1_c0_df, x='epoch', y='training_loss', linestyle='dotted', color='purple')
sns.lineplot(data=base2_c0_df, x='epoch', y='training_loss', linestyle='dotted', color='red')
sns.lineplot(data=base3_c0_df, x='epoch', y='training_loss', linestyle='dotted', color='blue')
sns.lineplot(data=base4_c0_df, x='epoch', y='training_loss', linestyle='dotted', color='green')
sns.lineplot(data=base5_c0_df, x='epoch', y='training_loss', linestyle='dotted', color='#EDB120')

sns.lineplot(data=base1_c1_df, x='epoch', y='training_loss', linestyle='dashed', color='purple')
sns.lineplot(data=base2_c1_df, x='epoch', y='training_loss', linestyle='dashed', color='red')
sns.lineplot(data=base3_c1_df, x='epoch', y='training_loss', linestyle='dashed', color='blue')
sns.lineplot(data=base4_c1_df, x='epoch', y='training_loss', linestyle='dashed', color='green')
sns.lineplot(data=base5_c1_df, x='epoch', y='training_loss', linestyle='dashed', color='#EDB120')

sns.lineplot(x=np.arange(0, 70), y=(base1_c0_df['server_training_loss'] + base1_c1_df['server_training_loss']) / 2, linestyle='dashdot', color='purple')
sns.lineplot(x=np.arange(0, 70), y=(base2_c0_df['server_training_loss'] + base2_c1_df['server_training_loss']) / 2, linestyle='dashdot', color='red')
sns.lineplot(x=np.arange(0, 70), y=(base3_c0_df['server_training_loss'] + base3_c1_df['server_training_loss']) / 2, linestyle='dashdot', color='blue')
sns.lineplot(x=np.arange(0, 70), y=(base4_c0_df['server_training_loss'] + base4_c1_df['server_training_loss']) / 2, linestyle='dashdot', color='green')
sns.lineplot(x=np.arange(0, 70), y=(base5_c0_df['server_training_loss'] + base5_c1_df['server_training_loss']) / 2, linestyle='dashdot', color='#EDB120')

plt.xlabel('Epochs')
plt.ylabel('Training Loss')
plt.xlim(left=0, right=70)

line1, = plt.plot([], linestyle='dotted', color='black')
line2, = plt.plot([], linestyle='dashed', color='black')
line3, = plt.plot([], linestyle='dashdot', color='black')
line4, = plt.plot([], linestyle='solid', color='blue')
line5, = plt.plot([], linestyle='solid', color='red')
line6, = plt.plot([], linestyle='solid', color='#EDB120')
line7, = plt.plot([], linestyle='solid', color='purple')
line8, = plt.plot([], linestyle='solid', color='green')

plt.legend([line1, line2, line3, line4, line5, line6, line7, line8], ['Client 1', 'Client 2', 'Server (avg)', 'λ = 0', 'λ = 0.2', 'λ = 0.3', 'λ = 0.5', 'λ = 0.9'], title='')
plt.savefig("fmnist-exp/Figures/Learning Curves/clients_server.pdf", dpi=100000)

_ = plt.show()

# %% [markdown]
# ## Validation Curves

# %% [markdown]
# ### Using validation loss

# %%
plt.figure(figsize=(12, 9))

sns.lineplot(data=base1_c0_df, x='epoch', y='validation_loss', linestyle='dotted', color='purple')
sns.lineplot(data=base2_c0_df, x='epoch', y='validation_loss', linestyle='dotted', color='red')
sns.lineplot(data=base3_c0_df, x='epoch', y='validation_loss', linestyle='dotted', color='blue')
sns.lineplot(data=base4_c0_df, x='epoch', y='validation_loss', linestyle='dotted', color='green')
sns.lineplot(data=base5_c0_df, x='epoch', y='validation_loss', linestyle='dotted', color='#EDB120')

sns.lineplot(data=base1_c1_df, x='epoch', y='validation_loss', linestyle='dashed', color='purple')
sns.lineplot(data=base2_c1_df, x='epoch', y='validation_loss', linestyle='dashed', color='red')
sns.lineplot(data=base3_c1_df, x='epoch', y='validation_loss', linestyle='dashed', color='blue')
sns.lineplot(data=base4_c1_df, x='epoch', y='validation_loss', linestyle='dashed', color='green')
sns.lineplot(data=base5_c1_df, x='epoch', y='validation_loss', linestyle='dashed', color='#EDB120')

plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.xlim(left=0, right=70)

line1, = plt.plot([], linestyle='dotted', color='black')
line2, = plt.plot([], linestyle='dashed', color='black')
line3, = plt.plot([], linestyle='solid', color='blue')
line4, = plt.plot([], linestyle='solid', color='red')
line5, = plt.plot([], linestyle='solid', color='#EDB120')
line6, = plt.plot([], linestyle='solid', color='purple')
line7, = plt.plot([], linestyle='solid', color='green')

plt.legend([line1, line2, line3, line4, line5, line6, line7], ['Client 1', 'Client 2', 'λ = 0', 'λ = 0.2', 'λ = 0.3', 'λ = 0.5', 'λ = 0.9'], title='', loc='upper right', fontsize='large')
plt.savefig("fmnist-exp/Figures/Validation Curves/clients_loss.pdf", dpi=100000)

_ = plt.show()

# %%
plt.figure(figsize=(12, 9))

sns.lineplot(data=base1_c0_df, x='epoch', y='validation_loss', linestyle='dotted', color='purple')
sns.lineplot(data=base2_c0_df, x='epoch', y='validation_loss', linestyle='dotted', color='red')
sns.lineplot(data=base3_c0_df, x='epoch', y='validation_loss', linestyle='dotted', color='blue')
sns.lineplot(data=base4_c0_df, x='epoch', y='validation_loss', linestyle='dotted', color='green')
sns.lineplot(data=base5_c0_df, x='epoch', y='validation_loss', linestyle='dotted', color='#EDB120')

sns.lineplot(data=base1_c0_df, x='epoch', y='server_validation_loss', linestyle='dashed', color='purple')
sns.lineplot(data=base2_c0_df, x='epoch', y='server_validation_loss', linestyle='dashed', color='red')
sns.lineplot(data=base3_c0_df, x='epoch', y='server_validation_loss', linestyle='dashed', color='blue')
sns.lineplot(data=base4_c0_df, x='epoch', y='server_validation_loss', linestyle='dashed', color='green')
sns.lineplot(data=base5_c0_df, x='epoch', y='server_validation_loss', linestyle='dashed', color='#EDB120')

plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.xlim(left=0, right=70)

line1, = plt.plot([], linestyle='dotted', color='black')
line2, = plt.plot([], linestyle='dashed', color='black')
line3, = plt.plot([], linestyle='solid', color='blue')
line4, = plt.plot([], linestyle='solid', color='red')
line5, = plt.plot([], linestyle='solid', color='#EDB120')
line6, = plt.plot([], linestyle='solid', color='purple')
line7, = plt.plot([], linestyle='solid', color='green')

plt.legend([line1, line2, line3, line4, line5, line6, line7], ['Client 1', 'Server', 'λ = 0', 'λ = 0.2', 'λ = 0.3', 'λ = 0.5', 'λ = 0.9'], title='', loc='upper right', fontsize='large')
plt.savefig("fmnist-exp/Figures/Validation Curves/client1_server_loss.pdf", dpi=100000)

_ = plt.show()

# %%
plt.figure(figsize=(12, 9))

sns.lineplot(data=base1_c1_df, x='epoch', y='validation_loss', linestyle='dotted', color='purple')
sns.lineplot(data=base2_c1_df, x='epoch', y='validation_loss', linestyle='dotted', color='red')
sns.lineplot(data=base3_c1_df, x='epoch', y='validation_loss', linestyle='dotted', color='blue')
sns.lineplot(data=base4_c1_df, x='epoch', y='validation_loss', linestyle='dotted', color='green')
sns.lineplot(data=base5_c1_df, x='epoch', y='validation_loss', linestyle='dotted', color='#EDB120')

sns.lineplot(data=base1_c1_df, x='epoch', y='server_validation_loss', linestyle='dashed', color='purple')
sns.lineplot(data=base2_c1_df, x='epoch', y='server_validation_loss', linestyle='dashed', color='red')
sns.lineplot(data=base3_c1_df, x='epoch', y='server_validation_loss', linestyle='dashed', color='blue')
sns.lineplot(data=base4_c1_df, x='epoch', y='server_validation_loss', linestyle='dashed', color='green')
sns.lineplot(data=base5_c1_df, x='epoch', y='server_validation_loss', linestyle='dashed', color='#EDB120')

plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.xlim(left=0, right=70)

line1, = plt.plot([], linestyle='dotted', color='black')
line2, = plt.plot([], linestyle='dashed', color='black')
line3, = plt.plot([], linestyle='solid', color='blue')
line4, = plt.plot([], linestyle='solid', color='red')
line5, = plt.plot([], linestyle='solid', color='#EDB120')
line6, = plt.plot([], linestyle='solid', color='purple')
line7, = plt.plot([], linestyle='solid', color='green')

plt.legend([line1, line2, line3, line4, line5, line6, line7], ['Client 2', 'Server', 'λ = 0', 'λ = 0.2', 'λ = 0.3', 'λ = 0.5', 'λ = 0.9'], title='', loc='upper right', fontsize='large')
plt.savefig("fmnist-exp/Figures/Validation Curves/client2_server_loss.pdf", dpi=100000)

_ = plt.show()

# %%
plt.figure(figsize=(12, 9))

sns.lineplot(data=base1_c0_df, x='epoch', y='validation_loss', linestyle='dotted', color='purple')
sns.lineplot(data=base2_c0_df, x='epoch', y='validation_loss', linestyle='dotted', color='red')
sns.lineplot(data=base3_c0_df, x='epoch', y='validation_loss', linestyle='dotted', color='blue')
sns.lineplot(data=base4_c0_df, x='epoch', y='validation_loss', linestyle='dotted', color='green')
sns.lineplot(data=base5_c0_df, x='epoch', y='validation_loss', linestyle='dotted', color='#EDB120')

sns.lineplot(data=base1_c1_df, x='epoch', y='validation_loss', linestyle='dashed', color='purple')
sns.lineplot(data=base2_c1_df, x='epoch', y='validation_loss', linestyle='dashed', color='red')
sns.lineplot(data=base3_c1_df, x='epoch', y='validation_loss', linestyle='dashed', color='blue')
sns.lineplot(data=base4_c1_df, x='epoch', y='validation_loss', linestyle='dashed', color='green')
sns.lineplot(data=base5_c1_df, x='epoch', y='validation_loss', linestyle='dashed', color='#EDB120')

sns.lineplot(x=np.arange(0, 70), y=(base1_c0_df['server_validation_loss'] + base1_c1_df['server_validation_loss']) / 2, linestyle='dashdot', color='purple')
sns.lineplot(x=np.arange(0, 70), y=(base2_c0_df['server_validation_loss'] + base2_c1_df['server_validation_loss']) / 2, linestyle='dashdot', color='red')
sns.lineplot(x=np.arange(0, 70), y=(base3_c0_df['server_validation_loss'] + base3_c1_df['server_validation_loss']) / 2, linestyle='dashdot', color='blue')
sns.lineplot(x=np.arange(0, 70), y=(base4_c0_df['server_validation_loss'] + base4_c1_df['server_validation_loss']) / 2, linestyle='dashdot', color='green')
sns.lineplot(x=np.arange(0, 70), y=(base5_c0_df['server_validation_loss'] + base5_c1_df['server_validation_loss']) / 2, linestyle='dashdot', color='#EDB120')

plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.xlim(left=0, right=70)

line1, = plt.plot([], linestyle='dotted', color='black')
line2, = plt.plot([], linestyle='dashed', color='black')
line3, = plt.plot([], linestyle='dashdot', color='black')
line3, = plt.plot([], linestyle='dashdot', color='black')
line4, = plt.plot([], linestyle='solid', color='blue')
line5, = plt.plot([], linestyle='solid', color='red')
line6, = plt.plot([], linestyle='solid', color='#EDB120')
line7, = plt.plot([], linestyle='solid', color='purple')
line8, = plt.plot([], linestyle='solid', color='green')

plt.legend([line1, line2, line3, line4, line5, line6, line7, line8], ['Client 1', 'Client 2', 'Server (avg)', 'λ = 0', 'λ = 0.2', 'λ = 0.3', 'λ = 0.5', 'λ = 0.9'], title='')
plt.savefig("fmnist-exp/Figures/Validation Curves/clients_server_loss.pdf", dpi=100000)

_ = plt.show()

# %% [markdown]
# ### Using validation accuracy

# %%
plt.figure(figsize=(12, 9))

sns.lineplot(data=base1_c0_df, x='epoch', y='validation_acc', linestyle='dotted', color='purple')
sns.lineplot(data=base2_c0_df, x='epoch', y='validation_acc', linestyle='dotted', color='red')
sns.lineplot(data=base3_c0_df, x='epoch', y='validation_acc', linestyle='dotted', color='blue')
sns.lineplot(data=base4_c0_df, x='epoch', y='validation_acc', linestyle='dotted', color='green')
sns.lineplot(data=base5_c0_df, x='epoch', y='validation_acc', linestyle='dotted', color='#EDB120')

sns.lineplot(data=base1_c1_df, x='epoch', y='validation_acc', linestyle='dashed', color='purple')
sns.lineplot(data=base2_c1_df, x='epoch', y='validation_acc', linestyle='dashed', color='red')
sns.lineplot(data=base3_c1_df, x='epoch', y='validation_acc', linestyle='dashed', color='blue')
sns.lineplot(data=base4_c1_df, x='epoch', y='validation_acc', linestyle='dashed', color='green')
sns.lineplot(data=base5_c1_df, x='epoch', y='validation_acc', linestyle='dashed', color='#EDB120')

plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.xlim(left=0, right=70)

line1, = plt.plot([], linestyle='dotted', color='black')
line2, = plt.plot([], linestyle='dashed', color='black')
line3, = plt.plot([], linestyle='solid', color='blue')
line4, = plt.plot([], linestyle='solid', color='red')
line5, = plt.plot([], linestyle='solid', color='#EDB120')
line6, = plt.plot([], linestyle='solid', color='purple')
line7, = plt.plot([], linestyle='solid', color='green')

plt.legend([line1, line2, line3, line4, line5, line6, line7], ['Client 1', 'Client 2', 'λ = 0', 'λ = 0.2', 'λ = 0.3', 'λ = 0.5', 'λ = 0.9'], title='', loc='lower center', fontsize='large')
plt.savefig("fmnist-exp/Figures/Validation Curves/clients_acc.pdf", dpi=100000)
_ = plt.show()

# %%
plt.figure(figsize=(12, 9))

sns.lineplot(data=base1_c0_df, x='epoch', y='validation_acc', linestyle='dotted', color='purple')
sns.lineplot(data=base2_c0_df, x='epoch', y='validation_acc', linestyle='dotted', color='red')
sns.lineplot(data=base3_c0_df, x='epoch', y='validation_acc', linestyle='dotted', color='blue')
sns.lineplot(data=base4_c0_df, x='epoch', y='validation_acc', linestyle='dotted', color='green')
sns.lineplot(data=base5_c0_df, x='epoch', y='validation_acc', linestyle='dotted', color='#EDB120')

sns.lineplot(data=base1_c0_df, x='epoch', y='server_validation_acc', linestyle='dashed', color='purple')
sns.lineplot(data=base2_c0_df, x='epoch', y='server_validation_acc', linestyle='dashed', color='red')
sns.lineplot(data=base3_c0_df, x='epoch', y='server_validation_acc', linestyle='dashed', color='blue')
sns.lineplot(data=base4_c0_df, x='epoch', y='server_validation_acc', linestyle='dashed', color='green')
sns.lineplot(data=base5_c0_df, x='epoch', y='server_validation_acc', linestyle='dashed', color='#EDB120')

plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.xlim(left=0, right=70)

line1, = plt.plot([], linestyle='dotted', color='black')
line2, = plt.plot([], linestyle='dashed', color='black')
line3, = plt.plot([], linestyle='solid', color='blue')
line4, = plt.plot([], linestyle='solid', color='red')
line5, = plt.plot([], linestyle='solid', color='#EDB120')
line6, = plt.plot([], linestyle='solid', color='purple')
line7, = plt.plot([], linestyle='solid', color='green')

plt.legend([line1, line2, line3, line4, line5, line6, line7], ['Client 1', 'Server', 'λ = 0', 'λ = 0.2', 'λ = 0.3', 'λ = 0.5', 'λ = 0.9'], title='', loc='lower center', fontsize='large')
plt.savefig("fmnist-exp/Figures/Validation Curves/client1_server_acc.pdf", dpi=100000)
_ = plt.show()

# %%
plt.figure(figsize=(12, 9))

sns.lineplot(data=base1_c1_df, x='epoch', y='validation_acc', linestyle='dotted', color='purple')
sns.lineplot(data=base2_c1_df, x='epoch', y='validation_acc', linestyle='dotted', color='red')
sns.lineplot(data=base3_c1_df, x='epoch', y='validation_acc', linestyle='dotted', color='blue')
sns.lineplot(data=base4_c1_df, x='epoch', y='validation_acc', linestyle='dotted', color='green')
sns.lineplot(data=base5_c1_df, x='epoch', y='validation_acc', linestyle='dotted', color='#EDB120')

sns.lineplot(data=base1_c1_df, x='epoch', y='server_validation_acc', linestyle='dashed', color='purple')
sns.lineplot(data=base2_c1_df, x='epoch', y='server_validation_acc', linestyle='dashed', color='red')
sns.lineplot(data=base3_c1_df, x='epoch', y='server_validation_acc', linestyle='dashed', color='blue')
sns.lineplot(data=base4_c1_df, x='epoch', y='server_validation_acc', linestyle='dashed', color='green')
sns.lineplot(data=base5_c1_df, x='epoch', y='server_validation_acc', linestyle='dashed', color='#EDB120')

plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.xlim(left=0, right=70)

line1, = plt.plot([], linestyle='dotted', color='black')
line2, = plt.plot([], linestyle='dashed', color='black')
line3, = plt.plot([], linestyle='solid', color='blue')
line4, = plt.plot([], linestyle='solid', color='red')
line5, = plt.plot([], linestyle='solid', color='#EDB120')
line6, = plt.plot([], linestyle='solid', color='purple')
line7, = plt.plot([], linestyle='solid', color='green')

plt.legend([line1, line2, line3, line4, line5, line6, line7], ['Client 2', 'Server', 'λ = 0', 'λ = 0.2', 'λ = 0.3', 'λ = 0.5', 'λ = 0.9'], title='', loc='lower center', fontsize='large')
plt.savefig("fmnist-exp/Figures/Validation Curves/client2_server_acc.pdf", dpi=100000)

_ = plt.show()

# %%
plt.figure(figsize=(12, 9))

sns.lineplot(data=base1_c0_df, x='epoch', y='validation_acc', linestyle='dotted', color='purple')
sns.lineplot(data=base2_c0_df, x='epoch', y='validation_acc', linestyle='dotted', color='red')
sns.lineplot(data=base3_c0_df, x='epoch', y='validation_acc', linestyle='dotted', color='blue')
sns.lineplot(data=base4_c0_df, x='epoch', y='validation_acc', linestyle='dotted', color='green')
sns.lineplot(data=base5_c0_df, x='epoch', y='validation_acc', linestyle='dotted', color='#EDB120')

sns.lineplot(data=base1_c1_df, x='epoch', y='validation_acc', linestyle='dashed', color='purple')
sns.lineplot(data=base2_c1_df, x='epoch', y='validation_acc', linestyle='dashed', color='red')
sns.lineplot(data=base3_c1_df, x='epoch', y='validation_acc', linestyle='dashed', color='blue')
sns.lineplot(data=base4_c1_df, x='epoch', y='validation_acc', linestyle='dashed', color='green')
sns.lineplot(data=base5_c1_df, x='epoch', y='validation_acc', linestyle='dashed', color='#EDB120')

sns.lineplot(x=np.arange(0, 70), y=(base1_c0_df['server_validation_acc'] + base1_c1_df['server_validation_acc']) / 2, linestyle='dashdot', color='purple')
sns.lineplot(x=np.arange(0, 70), y=(base2_c0_df['server_validation_acc'] + base2_c1_df['server_validation_acc']) / 2, linestyle='dashdot', color='red')
sns.lineplot(x=np.arange(0, 70), y=(base3_c0_df['server_validation_acc'] + base3_c1_df['server_validation_acc']) / 2, linestyle='dashdot', color='blue')
sns.lineplot(x=np.arange(0, 70), y=(base4_c0_df['server_validation_acc'] + base4_c1_df['server_validation_acc']) / 2, linestyle='dashdot', color='green')
sns.lineplot(x=np.arange(0, 70), y=(base5_c0_df['server_validation_acc'] + base5_c1_df['server_validation_acc']) / 2, linestyle='dashdot', color='#EDB120')

plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')

plt.xlim(left=0, right=70)

line1, = plt.plot([], linestyle='dotted', color='black')
line2, = plt.plot([], linestyle='dashed', color='black')
line3, = plt.plot([], linestyle='dashdot', color='black')
line3, = plt.plot([], linestyle='dashdot', color='black')
line4, = plt.plot([], linestyle='solid', color='blue')
line5, = plt.plot([], linestyle='solid', color='red')
line6, = plt.plot([], linestyle='solid', color='#EDB120')
line7, = plt.plot([], linestyle='solid', color='purple')
line8, = plt.plot([], linestyle='solid', color='green')

plt.legend([line1, line2, line3, line4, line5, line6, line7, line8], ['Client 1', 'Client 2', 'Server (avg)', 'λ = 0', 'λ = 0.2', 'λ = 0.3', 'λ = 0.5', 'λ = 0.9'], title='', loc='lower center')
plt.savefig("fmnist-exp/Figures/Validation Curves/clients_server_acc.svg", dpi=100000)

_ = plt.show()

# %% [markdown]
# ### Test Curves

# %%
df = pd.read_csv('fmnist-exp/Baseline_exps/test_accs.csv')
df.set_index('Unnamed: 0', inplace=True)
df
# Out:
#                                                          0  \
# Unnamed: 0
# client1          [89.9, 83.53, 79.07, 75.52, 72.63, 70.42]
# client1_server    [90.3, 83.28, 78.3, 74.61, 71.44, 69.22]
# client2           [95.68, 82.47, 73.1, 65.95, 60.32, 55.8]
# client2_server  [96.58, 82.18, 72.14, 64.44, 58.33, 53.55]
#
#                                                          1  \
# Unnamed: 0
# client1           [86.8, 84.43, 82.56, 81.14, 80.0, 79.28]
# client1_server  [90.28, 87.25, 84.83, 83.23, 81.84, 80.69]
# client2           [93.74, 84.23, 77.1, 72.1, 67.97, 64.78]
# client2_server    [94.9, 85.38, 78.41, 73.47, 69.7, 66.35]
#
#                                                          2  \
# Unnamed: 0
# client1         [76.84, 78.27, 79.27, 79.66, 80.28, 80.86]
# client1_server   [84.44, 84.5, 84.53, 84.39, 84.31, 84.21]
# client2         [84.88, 83.92, 82.71, 82.12, 81.42, 80.86]
# client2_server   [83.98, 84.07, 83.9, 84.04, 84.18, 84.21]
#
# ...

# %%
plt.figure(figsize=(12, 9))

sns.lineplot(x=np.arange(1.2, step=0.2), y=eval(df.iloc[0, 0]), linestyle='solid', color='purple')
sns.lineplot(x=np.arange(1.2, step=0.2), y=eval(df.iloc[0, 1]), linestyle='solid', color='red')
sns.lineplot(x=np.arange(1.2, step=0.2), y=eval(df.iloc[0, 2]), linestyle='solid', color='blue')
sns.lineplot(x=np.arange(1.2, step=0.2), y=eval(df.iloc[0, 3]), linestyle='solid', color='green')
sns.lineplot(x=np.arange(1.2, step=0.2), y=eval(df.iloc[0, 4]), linestyle='solid', color='#EDB120')

plt.xlabel('ρ')
plt.ylabel('Τest Accuracy')
#plt.xlim(left=0, right=70)

line1, = plt.plot([], linestyle='solid', color='blue')
line2, = plt.plot([], linestyle='solid', color='red')
line3, = plt.plot([], linestyle='solid', color='#EDB120')
line4, = plt.plot([], linestyle='solid', color='purple')
line5, = plt.plot([], linestyle='solid', color='green')

plt.legend([line1, line2, line3, line4, line5], ['λ = 0', 'λ = 0.2', 'λ = 0.3', 'λ = 0.5', 'λ = 0.9'], title='', loc='lower center', fontsize='large')
plt.savefig("fmnist-exp/Figures/Test Curves/client1_acc.pdf", dpi=100000)
_ = plt.show()

# %%
plt.figure(figsize=(12, 9))

sns.lineplot(x=np.arange(1.2, step=0.2), y=eval(df.iloc[1, 0]), linestyle='solid', color='purple')
sns.lineplot(x=np.arange(1.2, step=0.2), y=eval(df.iloc[1, 1]), linestyle='solid', color='red')
sns.lineplot(x=np.arange(1.2, step=0.2), y=eval(df.iloc[1, 2]), linestyle='solid', color='blue')
sns.lineplot(x=np.arange(1.2, step=0.2), y=eval(df.iloc[1, 3]), linestyle='solid', color='green')
sns.lineplot(x=np.arange(1.2, step=0.2), y=eval(df.iloc[1, 4]), linestyle='solid', color='#EDB120')

plt.xlabel('ρ')
plt.ylabel('Τest Accuracy')
#plt.xlim(left=0, right=70)

line1, = plt.plot([], linestyle='solid', color='blue')
line2, = plt.plot([], linestyle='solid', color='red')
line3, = plt.plot([], linestyle='solid', color='#EDB120')
line4, = plt.plot([], linestyle='solid', color='purple')
line5, = plt.plot([], linestyle='solid', color='green')

plt.legend([line1, line2, line3, line4, line5], ['λ = 0', 'λ = 0.2', 'λ = 0.3', 'λ = 0.5', 'λ = 0.9'], title='', loc='lower center', fontsize='large')
plt.savefig("fmnist-exp/Figures/Test Curves/client1_server_acc.pdf", dpi=100000)
_ = plt.show()

# %%
plt.figure(figsize=(12, 9))

sns.lineplot(x=np.arange(1.2, step=0.2), y=eval(df.iloc[2, 0]), linestyle='solid', color='purple')
sns.lineplot(x=np.arange(1.2, step=0.2), y=eval(df.iloc[2, 1]), linestyle='solid', color='red')
sns.lineplot(x=np.arange(1.2, step=0.2), y=eval(df.iloc[2, 2]), linestyle='solid', color='blue')
sns.lineplot(x=np.arange(1.2, step=0.2), y=eval(df.iloc[2, 3]), linestyle='solid', color='green')
sns.lineplot(x=np.arange(1.2, step=0.2), y=eval(df.iloc[2, 4]), linestyle='solid', color='#EDB120')

plt.xlabel('ρ')
plt.ylabel('Τest Accuracy')
#plt.xlim(left=0, right=70)

line1, = plt.plot([], linestyle='solid', color='blue')
line2, = plt.plot([], linestyle='solid', color='red')
line3, = plt.plot([], linestyle='solid', color='#EDB120')
line4, = plt.plot([], linestyle='solid', color='purple')
line5, = plt.plot([], linestyle='solid', color='green')

plt.legend([line1, line2, line3, line4, line5], ['λ = 0', 'λ = 0.2', 'λ = 0.3', 'λ = 0.5', 'λ = 0.9'], title='', loc='lower center', fontsize='large')
plt.savefig("fmnist-exp/Figures/Test Curves/client2_acc.pdf", dpi=100000)
_ = plt.show()

# %%
plt.figure(figsize=(12, 9))

sns.lineplot(x=np.arange(1.2, step=0.2), y=eval(df.iloc[3, 0]), linestyle='solid', color='purple')
sns.lineplot(x=np.arange(1.2, step=0.2), y=eval(df.iloc[3, 1]), linestyle='solid', color='red')
sns.lineplot(x=np.arange(1.2, step=0.2), y=eval(df.iloc[3, 2]), linestyle='solid', color='blue')
sns.lineplot(x=np.arange(1.2, step=0.2), y=eval(df.iloc[3, 3]), linestyle='solid', color='green')
sns.lineplot(x=np.arange(1.2, step=0.2), y=eval(df.iloc[3, 4]), linestyle='solid', color='#EDB120')

plt.xlabel('ρ')
plt.ylabel('Τest Accuracy')
#plt.xlim(left=0, right=70)

line1, = plt.plot([], linestyle='solid', color='blue')
line2, = plt.plot([], linestyle='solid', color='red')
line3, = plt.plot([], linestyle='solid', color='#EDB120')
line4, = plt.plot([], linestyle='solid', color='purple')
line5, = plt.plot([], linestyle='solid', color='green')

plt.legend([line1, line2, line3, line4, line5], ['λ = 0', 'λ = 0.2', 'λ = 0.3', 'λ = 0.5', 'λ = 0.9'], title='', loc='lower center', fontsize='large')
plt.savefig("fmnist-exp/Figures/Test Curves/client2_server_acc.pdf", dpi=100000)
_ = plt.show()

# %% [markdown]
# ### Using Various Entropy Thresholds

# %%
exp1_c1 = pd.read_csv('fmnist-exp\Baseline_exps\Base1\c1_entropies_acc.csv')
exp1_c2 = pd.read_csv('fmnist-exp\Baseline_exps\Base1\c2_entropies_acc.csv')

exp2_c1 = pd.read_csv('fmnist-exp\Baseline_exps\Base2\c1_entropies_acc.csv')
exp2_c2 = pd.read_csv('fmnist-exp\Baseline_exps\Base2\c2_entropies_acc.csv')

exp3_c1 = pd.read_csv('fmnist-exp\Baseline_exps\Base3\c1_entropies_acc.csv')
exp3_c2 = pd.read_csv('fmnist-exp\Baseline_exps\Base3\c2_entropies_acc.csv')

exp4_c1 = pd.read_csv('fmnist-exp\Baseline_exps\Base4\c1_entropies_acc.csv')
exp4_c2 = pd.read_csv('fmnist-exp\Baseline_exps\Base4\c2_entropies_acc.csv')

exp5_c1 = pd.read_csv('fmnist-exp\Baseline_exps\Base5\c1_entropies_acc.csv')
exp5_c2 = pd.read_csv('fmnist-exp\Baseline_exps\Base5\c2_entropies_acc.csv')

exp1_c1.drop('Unnamed: 0', axis=1, inplace=True), exp1_c2.drop('Unnamed: 0', axis=1, inplace=True)
exp2_c1.drop('Unnamed: 0', axis=1, inplace=True), exp2_c2.drop('Unnamed: 0', axis=1, inplace=True)
exp3_c1.drop('Unnamed: 0', axis=1, inplace=True), exp3_c2.drop('Unnamed: 0', axis=1, inplace=True)
exp4_c1.drop('Unnamed: 0', axis=1, inplace=True), exp4_c2.drop('Unnamed: 0', axis=1, inplace=True)
exp5_c1.drop('Unnamed: 0', axis=1, inplace=True), exp5_c2.drop('Unnamed: 0', axis=1, inplace=True)
# Out:
# (None, None)

# %%
exp1_c1
# Out:
#                   0.05                  0.4                  0.8  \
# 0      (90.3, 3560, 0)     (90.38, 1871, 0)     (90.66, 1136, 0)
# 1   (83.28, 4523, 963)   (83.42, 2623, 752)   (83.78, 1686, 550)
# 2   (78.3, 5488, 1928)  (78.51, 3373, 1502)  (79.06, 2233, 1097)
# 3  (74.61, 6457, 2897)  (74.83, 4123, 2252)  (75.36, 2759, 1623)
# 4  (71.44, 7428, 3868)  (71.77, 4878, 3007)  (72.34, 3322, 2186)
# 5  (69.22, 8397, 4837)  (69.53, 5624, 3753)  (70.14, 3869, 2733)
#
#                    1.2              2.3    r
# 0      (90.38, 477, 0)   (89.92, 10, 0)  0.0
# 1    (83.72, 812, 335)   (83.53, 19, 9)  0.2
# 2   (79.11, 1132, 655)  (79.09, 24, 14)  0.4
# 3   (75.45, 1431, 954)  (75.55, 32, 22)  0.6
# 4  (72.49, 1762, 1285)  (72.63, 41, 31)  0.8
# 5  (70.42, 2077, 1600)  (70.42, 45, 35)  1.0

# %% [markdown]
# ### Experiment 1

# %%
plt.figure(figsize=(12, 9))

sns.lineplot(x=exp1_c1['r'], y=[(eval(exp1_c1['0.05'][i])[0] + eval(exp1_c2['0.05'][i])[0]) / 2 for i in range(6)], linestyle='solid', color='purple')
sns.lineplot(x=exp1_c1['r'], y=[(eval(exp1_c1['0.4'][i])[0] + eval(exp1_c2['0.05'][i])[0]) / 2 for i in range(6)], linestyle='solid', color='red')
sns.lineplot(x=exp1_c1['r'], y=[(eval(exp1_c1['0.8'][i])[0] + eval(exp1_c2['0.05'][i])[0]) / 2 for i in range(6)], linestyle='solid', color='blue')
sns.lineplot(x=exp1_c1['r'], y=[(eval(exp1_c1['1.2'][i])[0] + eval(exp1_c2['0.05'][i])[0]) / 2 for i in range(6)], linestyle='solid', color='green')
sns.lineplot(x=exp1_c1['r'], y=[(eval(exp1_c1['2.3'][i])[0] + eval(exp1_c2['0.05'][i])[0]) / 2 for i in range(6)], linestyle='solid', color='#EDB120')

plt.xlabel('ρ')
plt.ylabel('Τest Accuracy')
#plt.xlim(left=0, right=70)

line1, = plt.plot([], linestyle='solid', color='purple')
line2, = plt.plot([], linestyle='solid', color='red')
line3, = plt.plot([], linestyle='solid', color='blue')
line4, = plt.plot([], linestyle='solid', color='green')
line5, = plt.plot([], linestyle='solid', color='#EDB120')

plt.legend([line1, line2, line3, line4, line5], ['Eth = 0.05', 'Eth = 0.4', 'Eth = 0.8', 'Eth = 1.2', 'Eth = 2.3', ], title='', loc='lower center', fontsize='large')
plt.savefig("fmnist-exp/Figures/Test Curves/exp1_entropy_server_acc.pdf", dpi=100000)
_ = plt.show()

# %%
plt.figure(figsize=(12, 9))

sns.lineplot(x=exp2_c1['r'], y=[(eval(exp2_c1['0.05'][i])[0] + eval(exp2_c2['0.05'][i])[0]) / 2 for i in range(6)], linestyle='solid', color='purple')
sns.lineplot(x=exp2_c1['r'], y=[(eval(exp2_c1['0.4'][i])[0] + eval(exp2_c2['0.05'][i])[0]) / 2 for i in range(6)], linestyle='solid', color='red')
sns.lineplot(x=exp2_c1['r'], y=[(eval(exp2_c1['0.8'][i])[0] + eval(exp2_c2['0.05'][i])[0]) / 2 for i in range(6)], linestyle='solid', color='blue')
sns.lineplot(x=exp2_c1['r'], y=[(eval(exp2_c1['1.2'][i])[0] + eval(exp2_c2['0.05'][i])[0]) / 2 for i in range(6)], linestyle='solid', color='green')
sns.lineplot(x=exp2_c1['r'], y=[(eval(exp2_c1['2.3'][i])[0] + eval(exp2_c2['0.05'][i])[0]) / 2 for i in range(6)], linestyle='solid', color='#EDB120')

plt.xlabel('ρ')
plt.ylabel('Τest Accuracy')

line1, = plt.plot([], linestyle='solid', color='purple')
line2, = plt.plot([], linestyle='solid', color='red')
line3, = plt.plot([], linestyle='solid', color='blue')
line4, = plt.plot([], linestyle='solid', color='green')
line5, = plt.plot([], linestyle='solid', color='#EDB120')

plt.legend([line1, line2, line3, line4, line5], ['Eth = 0.05', 'Eth = 0.4', 'Eth = 0.8', 'Eth = 1.2', 'Eth = 2.3', ], title='', loc='lower center', fontsize='large')
plt.savefig("fmnist-exp/Figures/Test Curves/exp2_entropy_server_acc.pdf", dpi=100000)
_ = plt.show()

# %%
plt.figure(figsize=(12, 9))

sns.lineplot(x=exp3_c1['r'], y=[(eval(exp3_c1['0.05'][i])[0] + eval(exp3_c2['0.05'][i])[0]) / 2 for i in range(6)], linestyle='solid', color='purple')
sns.lineplot(x=exp3_c1['r'], y=[(eval(exp3_c1['0.4'][i])[0] + eval(exp3_c2['0.05'][i])[0]) / 2 for i in range(6)], linestyle='solid', color='red')
sns.lineplot(x=exp3_c1['r'], y=[(eval(exp3_c1['0.8'][i])[0] + eval(exp3_c2['0.05'][i])[0]) / 2 for i in range(6)], linestyle='solid', color='blue')
sns.lineplot(x=exp3_c1['r'], y=[(eval(exp3_c1['1.2'][i])[0] + eval(exp3_c2['0.05'][i])[0]) / 2 for i in range(6)], linestyle='solid', color='green')
sns.lineplot(x=exp3_c1['r'], y=[(eval(exp3_c1['2.3'][i])[0] + eval(exp3_c2['0.05'][i])[0]) / 2 for i in range(6)], linestyle='solid', color='#EDB120')

plt.xlabel('ρ')
plt.ylabel('Τest Accuracy')

line1, = plt.plot([], linestyle='solid', color='purple')
line2, = plt.plot([], linestyle='solid', color='red')
line3, = plt.plot([], linestyle='solid', color='blue')
line4, = plt.plot([], linestyle='solid', color='green')
line5, = plt.plot([], linestyle='solid', color='#EDB120')

plt.legend([line1, line2, line3, line4, line5], ['Eth = 0.05', 'Eth = 0.4', 'Eth = 0.8', 'Eth = 1.2', 'Eth = 2.3', ], title='', loc='lower center', fontsize='large')
plt.savefig("fmnist-exp/Figures/Test Curves/exp3_entropy_server_acc.pdf", dpi=100000)
_ = plt.show()

# %%
plt.figure(figsize=(12, 9))

sns.lineplot(x=exp4_c1['r'], y=[(eval(exp4_c1['0.05'][i])[0] + eval(exp4_c2['0.05'][i])[0]) / 2 for i in range(6)], linestyle='solid', color='purple')
sns.lineplot(x=exp4_c1['r'], y=[(eval(exp4_c1['0.4'][i])[0] + eval(exp4_c2['0.05'][i])[0]) / 2 for i in range(6)], linestyle='solid', color='red')
sns.lineplot(x=exp4_c1['r'], y=[(eval(exp4_c1['0.8'][i])[0] + eval(exp4_c2['0.05'][i])[0]) / 2 for i in range(6)], linestyle='solid', color='blue')
sns.lineplot(x=exp4_c1['r'], y=[(eval(exp4_c1['1.2'][i])[0] + eval(exp4_c2['0.05'][i])[0]) / 2 for i in range(6)], linestyle='solid', color='green')
sns.lineplot(x=exp4_c1['r'], y=[(eval(exp4_c1['2.3'][i])[0] + eval(exp4_c2['0.05'][i])[0]) / 2 for i in range(6)], linestyle='solid', color='#EDB120')

plt.xlabel('ρ')
plt.ylabel('Τest Accuracy')

line1, = plt.plot([], linestyle='solid', color='purple')
line2, = plt.plot([], linestyle='solid', color='red')
line3, = plt.plot([], linestyle='solid', color='blue')
line4, = plt.plot([], linestyle='solid', color='green')
line5, = plt.plot([], linestyle='solid', color='#EDB120')

plt.legend([line1, line2, line3, line4, line5], ['Eth = 0.05', 'Eth = 0.4', 'Eth = 0.8', 'Eth = 1.2', 'Eth = 2.3', ], title='', loc='lower center', fontsize='large')
plt.savefig("fmnist-exp/Figures/Test Curves/exp4_entropy_server_acc.pdf", dpi=100000)
_ = plt.show()

# %%
plt.figure(figsize=(12, 9))

sns.lineplot(x=exp5_c1['r'], y=[(eval(exp5_c1['0.05'][i])[0] + eval(exp5_c2['0.05'][i])[0]) / 2 for i in range(6)], linestyle='solid', color='purple')
sns.lineplot(x=exp5_c1['r'], y=[(eval(exp5_c1['0.4'][i])[0] + eval(exp5_c2['0.05'][i])[0]) / 2 for i in range(6)], linestyle='solid', color='red')
sns.lineplot(x=exp5_c1['r'], y=[(eval(exp5_c1['0.8'][i])[0] + eval(exp5_c2['0.05'][i])[0]) / 2 for i in range(6)], linestyle='solid', color='blue')
sns.lineplot(x=exp5_c1['r'], y=[(eval(exp5_c1['1.2'][i])[0] + eval(exp5_c2['0.05'][i])[0]) / 2 for i in range(6)], linestyle='solid', color='green')
sns.lineplot(x=exp5_c1['r'], y=[(eval(exp5_c1['2.3'][i])[0] + eval(exp5_c2['0.05'][i])[0]) / 2 for i in range(6)], linestyle='solid', color='#EDB120')

plt.xlabel('ρ')
plt.ylabel('Τest Accuracy')

line1, = plt.plot([], linestyle='solid', color='purple')
line2, = plt.plot([], linestyle='solid', color='red')
line3, = plt.plot([], linestyle='solid', color='blue')
line4, = plt.plot([], linestyle='solid', color='green')
line5, = plt.plot([], linestyle='solid', color='#EDB120')

plt.legend([line1, line2, line3, line4, line5], ['Eth = 0.05', 'Eth = 0.4', 'Eth = 0.8', 'Eth = 1.2', 'Eth = 2.3', ], title='', loc='lower center', fontsize='large')
plt.savefig("fmnist-exp/Figures/Test Curves/exp5_entropy_server_acc.pdf", dpi=100000)
_ = plt.show()
